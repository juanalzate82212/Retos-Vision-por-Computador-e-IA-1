# %% [markdown]
# - Leer imagen a color con OpenCV

# %%
import cv2
from google.colab.patches import cv2_imshow

imagen = cv2.imread('imagen_reto_colores.jpg', cv2.IMREAD_COLOR)

# cv2_imshow(imagen)

# %% [markdown]
# - Imprimir forma (shape)

# %%
forma = imagen.shape

#print(forma)

# %% [markdown]
# - Extraer 5 zonas de interés homogeneas

# %%
rdi1 = imagen[870:920, 1405:1455] 
rdi2 = imagen[640:690, 1530:1580]
rdi3 = imagen[500:550, 1688:1738]
rdi4 = imagen[160:210, 260:310]
rdi5 = imagen[1152:1202, 2552:2602]

# cv2_imshow(rdi1)
# cv2_imshow(rdi2)
# cv2_imshow(rdi3)
# cv2_imshow(rdi4)
# cv2_imshow(rdi5)

# %% [markdown]
# - Extraer 1 zonas de interes no homogenea

# %%
rdi6 = imagen[640:720, 1666:1746]

# cv2_imshow(rdi6)
